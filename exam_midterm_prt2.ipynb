# %% [markdown]
# # Python et machine learning - Mageval 2 - Examen de mi-semestre

# %% [markdown]
# 5/3/2026

# %% [markdown]
# ## Partie 2 (/14 points)

# %% [markdown]
# Sujet : En utilisant la table de données Vahatra_defor_noNA.xlsx:
# 1. Créez une nouvelle table en sélectionnant uniquement les observations correspondant à des aires protégées créées après 1949 (2 points).
# 2. Dans cette table, créez une nouvelle variable appelée "treated" égale à "TRUE" si une aire protégée a été créée avant 2015 et à "FALSE" pour les aires protégées créées en 2015 ou après (2 points).
# 3. Estimez un modèle OLS dans lequel votre variable de réponse est le taux de déforestation sur la période 2000-2023 (aide: il s'agit de la variable de réponse que vous avez déjà utilisée pour les exercices à la maison) et la variable prédictive est la variable `treated`. Interprétez le signe, la taille et la significativité statistique du coefficient obtenu pour la variable `treated` (4 points).
# 4. Estimez maintenant trois modèles OLS complémentaires dans lesquels vous ajouterez à la liste des prédicteurs un polynome de degré 2, 3 et 4 respectivement pour la variable `dist_ville` (3 points).
# 5. Comparez chacun de ces trois modèles au premier en utilisant un test statistique pertinent. Est-ce qu'un des modèles semble plus prometteur pour prédire le taux de déforestation que le modèle simple utilisant `treated` comme seul prédicteur ? Si oui, lequel et pourquoi ? (3 points)
#
# Renseignez vos réponses dans ce notebook en utilisant de nouvelles cellules. Incluez des commentaires pour expliquer ce que fait votre code.
